# %%
import os

# %%
os.listdir("Drone_Agent")
# Out:
# ['Run_20250714_112557_(M,N)=(16,4)',
#  'Run_20250714_191738_(M,N)=(16,64)',
#  'Run_20250712_124222',
#  'Run_20250712_221350',
#  'Run_20250713_132519',
#  'Run_20250713_210442',
#  'Run_20250716_123312_(M,N,K,L,FixEv,Ey,PLoS)=(16,36,3,1,True,90.0,False)',
#  'Run_20250717_124913_(M,N,K,L,FixEv,Ey,PLoS)=(9,16,3,1,True,90.0,False)',
#  'Run_20250714_135623_(M,N)=(16,4)',
#  'Run_20250714_112708_(M,N)=(16,64)',
#  'Run_20250712_193635',
#  'Run_20250717_124921_(M,N,K,L,FixEv,Ey,PLoS)=(9,25,3,1,True,90.0,False)',
#  'Run_20250711_204008',
#  'Run_20250714_112636_(M,N)=(16,36)',
#  'Run_20250717_124927_(M,N,K,L,FixEv,Ey,PLoS)=(9,36,3,1,True,90.0,False)',
#  'Run_20250716_130131_(M,N,K,L,FixEv,Ey,PLoS)=(16,64,3,1,True,90.0,False)',
#  'Run_20250717_124845_(M,N,K,L,FixEv,Ey,PLoS)=(9,4,3,1,True,90.0,False)',
#  'AVRIS_300ep_1000steps.pdf',
#  'Run_20250712_193625',
#  'Run_20250716_123221_(M,N,K,L,FixEv,Ey,PLoS)=(16,4,3,1,True,90.0,False)',
#  'Run_20250714_145046_(M,N)=(16,36)',
# ...
